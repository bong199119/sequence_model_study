# %%
import numpy as np
import time

random_generator = np.random.default_rng()

def generate_data(n_features, n_values):
    features = random_generator.random((n_features, n_values))
    targets = random_generator.random((n_features))
    return features, targets


trainX, trainY = generate_data(5000, 4)
testX, testY = generate_data(5, 4)

# %%
print('trainX.shape', trainX.shape)
print('trainY.shape', trainY.shape)
# Out:
# trainX.shape (5000, 4)
# trainY.shape (5000,)

# %%
class RNN:
    def __init__(self):
        self.global_weight = [1, 1] # [Input, Recurrent Weight]
        self.local_weight = [0.001, 0.001]
        self.W_sign = [0, 0]

        self.eta_p = 1.2
        self.eta_n = 0.5

    def state_handler(self, input_x, previous_state):
        return input_x * self.global_weight[0] + previous_state * self.global_weight[1]

    def forward_propagation(self, X):
      # Computes the forward propagation of the RNN.
      S = np.zeros((X.shape[0], X.shape[1]+1))
      for k in range(0, X.shape[1]):
          next_state = self.state_handler(X[:,k], S[:,k])
          S[:,k+1] = next_state
      return S

    def backward_propagation(self, X, S, grad_out):
      # Computes the backward propagation of the RNN.
        grad_over_time = np.zeros(( X.shape[0], X.shape[1]+1 ))
        grad_over_time[:,-1] = grad_out

        wx_grad = 0
        wy_grad = 0
        for k in range(X.shape[1], 0, -1):
            wx_grad += np.sum( grad_over_time[:, k] * X[:, k-1] )
            wy_grad += np.sum( grad_over_time[:, k] * S[:, k-1] )

            grad_over_time[:, k-1] = grad_over_time[:, k] * self.global_weight[1]
        return (wx_grad, wy_grad), grad_over_time

    def update_rprop(self, X, Y, W_prev_sign, local_weight):
        S = self.forward_propagation(X)
        grad_out = 2 * (S[:, -1] - Y) / 500
        print(sum(grad_out))
        W_grads, _ = self.backward_propagation(X, S, grad_out)
#         print(W_grads)
        self.W_sign = np.sign(W_grads)

        for i, _ in enumerate(self.global_weight):
            if self.W_sign[i] == W_prev_sign[i]:
                local_weight[i] *= self.eta_p
            else:
                local_weight[i] *= self.eta_n
        self.local_weight = local_weight

    def train(self, X, Y, training_epochs):
        for epochs in range(training_epochs):
            print( self.W_sign, self.local_weight, self.global_weight)
            self.update_rprop(X, Y, self.W_sign, self.local_weight)

            for i, _ in enumerate(self.global_weight):
                if i == 0:
                    self.global_weight[i] -= self.W_sign[i] * self.local_weight[i]

# %%
rnn = RNN()
rnn.train(trainX, trainY, 200)

print (f"Targets are: {testY}")
y = rnn.forward_propagation(testX)[:, -1]
print (f"Predicted are: {y}")
# Out:
# [0, 0] [0.001, 0.001] [1, 1]
# 29.974425766225448
# [1. 1.] [0.0005, 0.0005] [0.9995, 1]
# 29.954376321006716
# [1. 1.] [0.0006, 0.0006] [0.9989, 1]
# 29.9303169867441
# [1. 1.] [0.0007199999999999999, 0.0007199999999999999] [0.99818, 1]
# 29.90144578562907
# [1. 1.] [0.0008639999999999999, 0.0008639999999999999] [0.997316, 1]
# 29.866800344291146
# [1. 1.] [0.0010367999999999998, 0.0010367999999999998] [0.9962792, 1]
# 29.825225814685393
[0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [9.44128704499753e-18, 613346.236040075] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.1329544453997036e-17, 736015.4832480899] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.3595453344796443e-17, 883218.5798977079] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.6314544013755732e-17, 1059862.2958772494] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [8.157272006877866e-18, 1271834.7550526992] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [9.78872640825344e-18, 1526201.7060632391] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.1746471689904127e-17, 1831442.0472758869] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.409576602788495e-17, 2197730.4567310642] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [7.047883013942475e-18, 2637276.548077277] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [8.45745961673097e-18, 3164731.857692732] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.0148951540077163e-17, 3797678.2292312784] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.2178741848092595e-17, 4557213.875077534] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.4614490217711115e-17, 5468656.65009304] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [7.307245108855558e-18, 6562387.980111648] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [8.768694130626668e-18, 7874865.576133978] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.0522432956752002e-17, 9449838.691360774] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.2626919548102403e-17, 11339806.429632928] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.5152303457722882e-17, 13607767.715559514] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [7.576151728861441e-18, 16329321.258671416] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [9.091382074633728e-18, 19595185.510405697] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.0909658489560474e-17, 23514222.612486836] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.3091590187472568e-17, 28217067.134984203] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.570990822496708e-17, 33860480.561981045] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [7.85495411248354e-18, 40632576.674377255] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [9.425944934980249e-18, 48759092.009252705] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.1311133921976298e-17, 58510910.41110324] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.3573360706371557e-17, 70213092.49332389] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.628803284764587e-17, 84255710.99198867] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [8.144016423822934e-18, 101106853.1903864] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [9.77281970858752e-18, 121328223.82846367] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.1727383650305025e-17, 145593868.5941564] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.407286038036603e-17, 174712642.3129877] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [7.036430190183015e-18, 209655170.7755852] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [8.443716228219618e-18, 251586204.93070224] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.013245947386354e-17, 301903445.9168427] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.2158951368636249e-17, 362284135.1002112] [0.23345270701017987, 1]
# -0.7632701505733079
# [ 1. -1.] [1.4590741642363498e-17, 434740962.12025344] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [7.295370821181749e-18, 521689154.54430413] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [8.754444985418099e-18, 626026985.4531649] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.0505333982501718e-17, 751232382.5437979] [0.23345270701017984, 1]
# -0.763270150573309
# [-1. -1.] [1.2606400779002062e-17, 901478859.0525573] [0.23345270701017984, 1]
# -0.763270150573309
# Targets are: [0.22009432 0.35327569 0.63933715 0.98243468 0.4259547 ]
# Predicted are: [0.31610693 0.79106357 0.43122618 0.31277305 0.5393427 ]

# %%
global_weight = [1, 1]

# %%
def state_handler(input_x, previous_state):
        return input_x * global_weight[0] + previous_state * global_weight[1]

# %%
X = trainX
S = np.zeros((X.shape[0], X.shape[1]+1))

# %%
for k in range(0, X.shape[1]):
  next_state = state_handler(X[:,k], S[:,k])
  S[:,k+1] = next_state

# %%
S.shape
# Out:
# (5000, 5)

# %%
trainX.shape
# Out:
# (5000, 4)

# %%
def state_handler(self, input_x, previous_state):
        return input_x * self.global_weight[0] + previous_state * self.global_weight[1]

# %%
S[:,0]*[1, 1][1]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
S[:,0].shape
# Out:
# (5000,)

# %%
[1, 1][1]
# Out:
# 1

# %%
Y = trainY

# %%
grad_out = 2 * (S[:, -1] - Y) / 500

# %%
grad_out
# Out:
# array([0.00767497, 0.00261783, 0.00379138, ..., 0.00989653, 0.00303773,
#        0.00935126])

# %%
grad_over_time = np.zeros(( X.shape[0], X.shape[1]+1 ))
grad_over_time[:,-1] = grad_out

# %%
S
# Out:
# array([[0.        , 0.31432279, 0.44660938, 1.37835905, 2.19350278],
#        [0.        , 0.4668691 , 0.60265939, 1.42648053, 1.54897401],
#        [0.        , 0.62458618, 1.16765573, 1.4902387 , 1.63806539],
#        ...,
#        [0.        , 0.9532179 , 1.5233587 , 2.16728477, 2.58377996],
#        [0.        , 0.52922652, 0.68950846, 0.90395224, 1.40365043],
#        [0.        , 0.15516796, 1.07445864, 1.94538891, 2.56130436]])

# %%
grad_over_time
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.00767497],
#        [0.        , 0.        , 0.        , 0.        , 0.00261783],
#        [0.        , 0.        , 0.        , 0.        , 0.00379138],
#        ...,
#        [0.        , 0.        , 0.        , 0.        , 0.00989653],
#        [0.        , 0.        , 0.        , 0.        , 0.00303773],
#        [0.        , 0.        , 0.        , 0.        , 0.00935126]])

# %%
wx_grad = 0
wy_grad = 0
for k in range(X.shape[1], 0, -1):
    wx_grad += np.sum( grad_over_time[:, k] * X[:, k-1] )
    wy_grad += np.sum( grad_over_time[:, k] * S[:, k-1] )
    grad_over_time[:, k-1] = grad_over_time[:, k] * 1

# %%
wx_grad
# Out:
# 66.83205762883043

# %%
wy_grad
# Out:
# 100.40356368735185

# %%
grad_over_time
# Out:
# array([[0.00767497, 0.00767497, 0.00767497, 0.00767497, 0.00767497],
#        [0.00261783, 0.00261783, 0.00261783, 0.00261783, 0.00261783],
#        [0.00379138, 0.00379138, 0.00379138, 0.00379138, 0.00379138],
#        ...,
#        [0.00989653, 0.00989653, 0.00989653, 0.00989653, 0.00989653],
#        [0.00303773, 0.00303773, 0.00303773, 0.00303773, 0.00303773],
#        [0.00935126, 0.00935126, 0.00935126, 0.00935126, 0.00935126]])

# %%
W_grads = (wx_grad, wy_grad)

# %%
W_sign = np.sign(W_grads)

# %%
W_sign
# Out:
# array([1., 1.])

# %%
global_weight
W_prev_sign = [0, 0]
local_weight = [0.001, 0.001]
eta_p = 1.2
eta_n = 0.5

# %%
for i, _ in enumerate(global_weight):
    if W_sign[i] == W_prev_sign[i]:
        local_weight[i] *= eta_p
    else:
        local_weight[i] *= eta_n
local_weight = local_weight

# %%
W_sign
# Out:
# array([1., 1.])

# %%
local_weight
# Out:
# [0.0005, 0.0005]

# %%
for i, _ in enumerate(global_weight):
        global_weight[i] -= W_sign[i] * local_weight[i]

# %%
global_weight
# Out:
# [0.9995, 0.9995]

# %%
W_sign
# Out:
# array([1., 1.])

# %%
local_weight
# Out:
# [0.0005, 0.0005]

# %%
 grad_over_time[:, 4]*X[:, 4-1]
# Out:
# array([0.0062562 , 0.00032067, 0.00056047, ..., 0.00412186, 0.00151795,
#        0.00575958])

# %%
# Out:
# array([0.81514372, 0.12249348, 0.14782669, ..., 0.41649519, 0.49969818,
#        0.61591545])

# %%
np.array([1,2,3])*np.array([1,2,3])
# Out:
# array([1, 4, 9])
